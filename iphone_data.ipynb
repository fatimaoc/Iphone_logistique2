# %% [markdown]
# ## Question 2 : Récupérer les données CSV avec la librairie Panda

# %%
import pandas as pd

#import du fichier UserData.csv avec pandas

User_data = pd.read_csv("/home/fatimam/Documents/formation_ia/P4 Regression logistique/UserData.csv")
df = User_data

#affichage de la DataFrame
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
# connection à mysql
# mysql -u root -p
# SHOW DATABASES;
# CREATE DATABASE UserIphone;
# USE UserIphone
# SHOW tables;
# CREATE TABLE

# %% [markdown]
# ## Question 5 : Visualisation et Analyse des données avec les librairies Matplotlib et Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1/ Visualisation avec Python et la librairie Matplotlib

# %%
plt.figure(figsize =(12,8))
plt.title("Repartition des salaires en fonction de l'âge")
plt.xlabel("x-label")
plt.ylabel("y-label")
plt.scatter (df.Age,df.EstimatedSalary,color ='b')

# %%
df.hist(figsize = (12,8))
# Out:
# array([[<AxesSubplot:title={'center':'User ID'}>,
#         <AxesSubplot:title={'center':'Age'}>],
#        [<AxesSubplot:title={'center':'EstimatedSalary'}>,
#         <AxesSubplot:title={'center':'Purchased'}>]], dtype=object)

# %%
plt.figure(figsize =(12,8))
plt.title("Histogrammes de la fréquence des  salaires avec moyenne et ligne médiane")
plt.axvline(df.EstimatedSalary.mean (),c ='C1')
plt.axvline(df.EstimatedSalary.median(),c = 'C2',linestyle=':')
plt.axvline(df.EstimatedSalary.quantile(0.25),c = 'C3',linestyle=':')
plt.axvline(df.EstimatedSalary.quantile(0.75),c = 'C4',linestyle=':')
df.EstimatedSalary.plot(kind ='hist',histtype ='step',bins=30)

plt.axis(xmin=0,xmax=155000)
# Out:
# (0.0, 155000.0, 0.0, 32.55)

# %%
extract = df[['Age','Gender','EstimatedSalary']]

# %%
extract
# Out:
#      Age  Gender  EstimatedSalary
# 0     19    Male            19000
# 1     35    Male            20000
# 2     26  Female            43000
# 3     27  Female            57000
# 4     19    Male            76000
# ..   ...     ...              ...
# 395   46  Female            41000
# 396   51    Male            23000
# 397   50  Female            20000
# 398   36    Male            33000
# 399   49  Female            36000
#
# [400 rows x 3 columns]

# %%
import matplotlib
pd.plotting.scatter_matrix(extract,figsize=(10,10))
# Out:
# array([[<AxesSubplot:xlabel='Age', ylabel='Age'>,
#         <AxesSubplot:xlabel='EstimatedSalary', ylabel='Age'>],
#        [<AxesSubplot:xlabel='Age', ylabel='EstimatedSalary'>,
#         <AxesSubplot:xlabel='EstimatedSalary', ylabel='EstimatedSalary'>]],
#       dtype=object)

# %% [markdown]
# ### 2/ Visualisation avec Python et la librairie Seaborn

# %%
import numpy as np
import seaborn as sns
sns.set()

# %%
sns.pairplot(df)

# %%
sns.catplot (x = 'Purchased', y= 'Age',data = df, kind = 'swarm',hue ='Gender',aspect=2, height =4)

# %%
sns.catplot (x = 'Purchased', y= 'EstimatedSalary',data = df, kind = 'swarm',hue ='Age',aspect=2, height =4)

# %%
sns.pairplot(extract, hue = 'Gender', height =2.5)

# %% [markdown]
# ## Question 6  : Résolution du cas d'étude avec Scikit-Learn
